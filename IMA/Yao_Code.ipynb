# %% [markdown]
# # Import

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Transformation

# %% [markdown]
# ## Use `xml.etree.ElementTree` module parse data

# %%
def convert_xml_to_dataframe(file_path):
    '''
    convert xml file into a dataframe format
    '''
    tree = ET.parse(file_path)
    root = tree.getroot()
    # parse scenatio dates
    date_list = []
    for date in root.iter('scenarioDates'):
        date_list.append(date.text.split())
    # dimensionality
    date_list = date_list[0]
    # parse desk names
    desk_list = []
    for desk in root.iter('value'):
        if 'DESK' in desk.text:
            desk_list.append(desk.text.split())
    # dimensionality
    desk_list = [desk_list[i][0] for i in range(len(desk_list))]
    # parst risk class names
    risk_class_list = []
    for risk_class in root.iter('pvRiskClassList'):
        risk_class_list.append(risk_class.text.split())
    # dimensionality
    risk_class_list = risk_class_list[0]
    # combine desk names with risk class names
    desk_class_list = []
    for desk in desk_list:
        for risk_class in risk_class_list:
            desk_class_list.append(str(desk) + '_' + str(risk_class))
    # parst pv value
    pv_list = []
    for pv in root.iter('pvList'):
        pv_list.append(pv.text.split())
    # create a dataframe and change data type to float
    PV = pd.DataFrame(pv_list, dtype=float).T
    PV.columns = desk_class_list
    PV = PV.sort_index(axis=1)
    PV.insert(0, 'DATE', date_list)
    return PV

# %% [markdown]
# # Read data

# %%
sp_pv = convert_xml_to_dataframe('10Y_P&L.xml')

# %%
sp_pv.head()
# Out:
#          DATE  DESK4_A_TOTAL  DESK4_B_TOTAL  DESK4_C_TOTAL  DESK4_D_TOTAL  \
# 0  2006-09-01  -36413.488550   39195.963364  -45139.233907  -1.070008e+06
# 1  2006-09-04   -1178.214171    4216.087228  -10280.017152  -1.068437e+06
# 2  2006-09-05   19912.455767  -16719.338608   10592.403697  -1.069343e+06
# 3  2006-09-06   20027.938821  -17311.796210   10916.628181  -1.069812e+06
# 4  2006-09-07   26817.860586  -23885.911339   17681.553907  -1.069897e+06
#
#    DESK4_E_TOTAL  DESK4_F_TOTAL  DESK4_G_TOTAL  DESK4_G_TOTAL  DESK4_H_TOTAL  \
# 0  -1.069001e+06  185054.848215  -1.724339e+06  808192.664841   -9308.402859
# 1  -1.067430e+06  162375.528238  -1.721056e+06  830023.179129   -9555.320378
# 2  -1.068336e+06  205649.216115  -1.722798e+06  786528.653362   -9610.516448
# 3  -1.068805e+06  181776.753119  -1.723964e+06  807871.263783   -9458.532889
# 4  -1.068889e+06  167246.304529  -1.724250e+06  819146.481139   -9503.316217
#
#    DESK4_I_TOTAL  DESK4_J_TOTAL  DESK4_K_TOTAL
# 0  147896.872462   -7624.302597   10992.502642
# 1  108767.072623   -7871.212000   11239.428278
# 2   85441.295376   -7926.396303   11294.636115
# 3   85247.637803   -7774.438839   11142.626460
# 4   77658.255402   -7819.207852   11187.424105

# %% [markdown]
# # Get Stress Period

# %%
# get profit and lost by subtracing the next day's present value
sp_pl = sp_pv.iloc[:, 1:].diff(periods=-1)
sp_pl.insert(0, "DATE", sp_pv.DATE)
sp_pl = sp_pl[:-1]

# %%
sp_pl.head()
# Out:
#          DATE  DESK4_A_TOTAL  DESK4_B_TOTAL  DESK4_C_TOTAL  DESK4_D_TOTAL  \
# 0  2006-09-01  -35235.274378   34979.876136  -34859.216756   -1571.459084
# 1  2006-09-04  -21090.669938   20935.425836  -20872.420849     906.724476
# 2  2006-09-05    -115.483054     592.457602    -324.224484     468.705880
# 3  2006-09-06   -6789.921765    6574.115129   -6764.925725      84.417662
# 4  2006-09-07  -48141.100814   47992.285290  -48022.796045    -843.668979
#
#    DESK4_E_TOTAL  DESK4_F_TOTAL  DESK4_G_TOTAL  DESK4_G_TOTAL  DESK4_H_TOTAL  \
# 0   -1570.458170   22679.319978   -3282.918731  -21830.514288     246.917520
# 1     906.198418  -43273.687877    1742.068718   43494.525767      55.196070
# 2     468.331781   23872.462996    1165.960571  -21342.610421    -151.983559
# 3      84.422745   14530.448590     285.938608  -11275.217356      44.783329
# 4    -843.089423   -9521.832758   -1855.504737    -314.697334      -3.543640
#
#    DESK4_I_TOTAL  DESK4_J_TOTAL  DESK4_K_TOTAL
# 0   39129.799838     246.909404    -246.925636
# 1   23325.777248      55.184303     -55.207837
# 2     193.657573    -151.957464     152.009654
# 3    7589.382401      44.769013     -44.797644
# 4   53524.027676      -3.537871       3.549410

# %%
# sum each 250 days period profit and lost
sp_pl_sum = sp_pl.iloc[:, 1:].rolling(250).sum()
sp_pl_sum.insert(0, "DATE", sp_pl.DATE)
sp_pl_sum = sp_pl_sum[250:]
sp_pl_sum.head()
# Out:
#            DATE  DESK4_A_TOTAL  DESK4_B_TOTAL  DESK4_C_TOTAL  DESK4_D_TOTAL  \
# 250  2007-08-21   45829.832661  -43207.790284   46640.246325     192.371824
# 251  2007-08-22   41816.047060  -44067.081671   42585.047983    1173.221240
# 252  2007-08-23   96282.748588  -95890.862549   96172.872860    1917.903566
# 253  2007-08-24   28375.535891  -28824.656148   29906.776749    2604.125362
# 254  2007-08-27   58831.778516  -58508.982774   58318.464043   -2245.469586
#
#      DESK4_E_TOTAL  DESK4_F_TOTAL  DESK4_G_TOTAL  DESK4_G_TOTAL  \
# 250     192.464354  -21114.864379     768.089721   45426.615471
# 251    1172.604926   34203.043953    3103.848553  -20649.430778
# 252    1916.437672   48030.357440    3735.824630  -48330.653424
# 253    2602.067771    -575.358281    5197.972993  -21641.521244
# 254   -2243.864824   14286.073999   -4643.989265  -32594.960290
#
#      DESK4_H_TOTAL  DESK4_I_TOTAL  DESK4_J_TOTAL  DESK4_K_TOTAL
# 250     308.391575  -51644.553240     308.364775    -308.418376
# 251      95.796773  -47360.374952      95.787139     -95.806407
# 252    -252.376179 -107476.375920    -252.344729     252.407629
# 253    1010.207245  -32218.646688    1010.056111   -1010.358379
# 254      21.488361  -64977.554931      21.518822     -21.457900

# %%
# combine duplicated columns
sp_pl_sum = sp_pl_sum.groupby(sp_pl_sum.columns, axis=1).sum()
# get the minimum value list
sp_pl_sum_min = sp_pl_sum.min()[1:]
sp_pl_sum_min
# Out:
# DESK4_A_TOTAL    -664750
# DESK4_B_TOTAL    -725398
# DESK4_C_TOTAL    -660331
# DESK4_D_TOTAL   -12317.2
# DESK4_E_TOTAL   -12307.6
# DESK4_F_TOTAL    -239251
# DESK4_G_TOTAL    -294454
# DESK4_H_TOTAL   -12971.9
# DESK4_I_TOTAL    -809562
# DESK4_J_TOTAL   -12971.3
# DESK4_K_TOTAL   -10826.2
# dtype: object

# %%
# find stress period end date
count_desk = 0
end_date_index = []
sp_end_date = []
for count_desk in range(sp_pl_sum_min.size):
    index = sp_pl_sum[sp_pl_sum[sp_pl_sum_min.index[count_desk]]== sp_pl_sum_min.values[count_desk]].index[0]
    end_date_index.append(index)
    sp_end_date.append(sp_pl_sum.iloc[index].DATE)
sp_end_date
# Out:
# ['2010-11-22',
#  '2010-03-05',
#  '2010-11-22',
#  '2010-08-18',
#  '2010-08-18',
#  '2010-11-22',
#  '2009-11-11',
#  '2009-01-08',
#  '2010-03-05',
#  '2009-01-08',
#  '2009-12-24']

# %%
# find stress period start date
sp_start_date = []
for i in range(len(end_date_index)):
    sp_start_date.append(sp_pl_sum.iloc[end_date_index[i]-250].DATE)
sp_start_date
# Out:
# ['2009-12-03',
#  '2009-03-18',
#  '2009-12-03',
#  '2009-08-31',
#  '2009-08-31',
#  '2009-12-03',
#  '2008-11-24',
#  '2008-01-22',
#  '2009-03-18',
#  '2008-01-22',
#  '2009-01-08']

# %%
# store into dataframe
stress_period = pd.DataFrame({'Desk' : sp_pl_sum_min.index, 'start_date' : sp_start_date, 'end_date' : sp_end_date})

# %%
stress_period
# Out:
#              Desk  start_date    end_date
# 0   DESK4_A_TOTAL  2009-12-03  2010-11-22
# 1   DESK4_B_TOTAL  2009-03-18  2010-03-05
# 2   DESK4_C_TOTAL  2009-12-03  2010-11-22
# 3   DESK4_D_TOTAL  2009-08-31  2010-08-18
# 4   DESK4_E_TOTAL  2009-08-31  2010-08-18
# 5   DESK4_F_TOTAL  2009-12-03  2010-11-22
# 6   DESK4_G_TOTAL  2008-11-24  2009-11-11
# 7   DESK4_H_TOTAL  2008-01-22  2009-01-08
# 8   DESK4_I_TOTAL  2009-03-18  2010-03-05
# 9   DESK4_J_TOTAL  2008-01-22  2009-01-08
# 10  DESK4_K_TOTAL  2009-01-08  2009-12-24
