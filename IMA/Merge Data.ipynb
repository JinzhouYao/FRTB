# %%
with open('FED_Team3.txt') as team3:
    data_3 = team3.readlines()
    lines = []
    for line_3 in data_3:
        if 'DATE' in line_3: 
            lines.append((line_3.replace(" ","")))
lines
# Out:
# ['DATE31/08/2006\n',
#  'DATE01/09/2006\n',
#  'DATE04/09/2006\n',
#  'DATE05/09/2006\n',
#  'DATE06/09/2006\n',
#  'DATE07/09/2006\n',
#  'DATE08/09/2006\n',
#  'DATE11/09/2006\n',
#  'DATE12/09/2006\n',
#  'DATE13/09/2006\n',
#  'DATE14/09/2006\n',
#  'DATE15/09/2006\n',
#  'DATE18/09/2006\n',
#  'DATE19/09/2006\n',
#  'DATE20/09/2006\n',
#  'DATE21/09/2006\n',
#  'DATE22/09/2006\n',
#  'DATE25/09/2006\n',
#  'DATE26/09/2006\n',
#  'DATE27/09/2006\n',
#  'DATE28/09/2006\n',
#  'DATE29/09/2006\n',
#  'DATE02/10/2006\n',
#  'DATE03/10/2006\n',
#  'DATE04/10/2006\n',
#  'DATE05/10/2006\n',
#  'DATE06/10/2006\n',
#  'DATE09/10/2006\n',
#  'DATE10/10/2006\n',
#  'DATE11/10/2006\n',
#  'DATE12/10/2006\n',
#  'DATE13/10/2006\n',
#  'DATE16/10/2006\n',
#  'DATE17/10/2006\n',
#  'DATE18/10/2006\n',
#  'DATE19/10/2006\n',
#  'DATE20/10/2006\n',
#  'DATE23/10/2006\n',
#  'DATE24/10/2006\n',
#  'DATE25/10/2006\n',
#  'DATE26/10/2006\n',
#  'DATE27/10/2006\n',
#  'DATE30/10/2006\n',
# ...

# %%
with open('FED_Team4.txt') as team4:
    data_4 = team4.readlines()
    lines4 = []
    for line_4 in data_4:
        if "DATE" in line_4:
            lines4.append(line_4.replace(" ",""))
lines4
# Out:
# ['DATE31/08/2006\n',
#  'DATE01/09/2006\n',
#  'DATE04/09/2006\n',
#  'DATE05/09/2006\n',
#  'DATE06/09/2006\n',
#  'DATE07/09/2006\n',
#  'DATE08/09/2006\n',
#  'DATE11/09/2006\n',
#  'DATE12/09/2006\n',
#  'DATE13/09/2006\n',
#  'DATE14/09/2006\n',
#  'DATE15/09/2006\n',
#  'DATE18/09/2006\n',
#  'DATE19/09/2006\n',
#  'DATE20/09/2006\n',
#  'DATE21/09/2006\n',
#  'DATE22/09/2006\n',
#  'DATE25/09/2006\n',
#  'DATE26/09/2006\n',
#  'DATE27/09/2006\n',
#  'DATE28/09/2006\n',
#  'DATE29/09/2006\n',
#  'DATE02/10/2006\n',
#  'DATE03/10/2006\n',
#  'DATE04/10/2006\n',
#  'DATE05/10/2006\n',
#  'DATE06/10/2006\n',
#  'DATE09/10/2006\n',
#  'DATE10/10/2006\n',
#  'DATE11/10/2006\n',
#  'DATE12/10/2006\n',
#  'DATE13/10/2006\n',
#  'DATE16/10/2006\n',
#  'DATE17/10/2006\n',
#  'DATE18/10/2006\n',
#  'DATE19/10/2006\n',
#  'DATE20/10/2006\n',
#  'DATE23/10/2006\n',
#  'DATE24/10/2006\n',
#  'DATE25/10/2006\n',
#  'DATE26/10/2006\n',
#  'DATE27/10/2006\n',
#  'DATE30/10/2006\n',
# ...

# %%
repeat = []
for i in lines:
    if i in lines4:
        repeat.append(i)

# %%
len(lines)
# Out:
# 2610

# %%
len(lines4)
# Out:
# 2610
